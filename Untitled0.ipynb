# %% [markdown]
# <a href="https://colab.research.google.com/github/EmanuelKroner/EmanuelKroner/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nova seção

# %% [markdown]
# ## Triângulo

# %%
base_triangulo = int(input("Digite a base do triângulo"))
altura_triangulo = int(input("Digite a altura do triângulo"))
area_triangulo = (base_triangulo * altura_triangulo) / 2
print(f"A área do triângulo é {area_triangulo} m²")
# Out:
# Digite a base do triângulo90
# Digite a altura do triângulo90
# A área do triângulo é 4050.0 m²
